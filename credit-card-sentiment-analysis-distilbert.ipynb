# %%
# Analyze sentiment of customer reviews related to credit card services using DistilBERT
# %pip install transformers torch
import torch
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification

# Load pre-trained model and tokenizer
model_name = "distilbert-base-uncased"
tokenizer = DistilBertTokenizer.from_pretrained(model_name)
model = DistilBertForSequenceClassification.from_pretrained(model_name, num_labels=2)

# Function to perform sentiment analysis
def analyze_sentiment(review):
    inputs = tokenizer(review, return_tensors="pt", truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    logits = outputs.logits
    sentiment = torch.argmax(logits, dim=1).item()
    return "Positive" if sentiment == 1 else "Negative"

# Perform sentiment analysis on the credit card reviews
for review in credit_card_reviews:
    sentiment = analyze_sentiment(review)
    print(f"Review: {review}")
    print(f"Sentiment: {sentiment}\n")

# Example customer reviews related to credit card services
credit_card_reviews = [
        "The foreign transaction fees are too high.",
        "I like the travel rewards.",
        "The card offers good rewards on fitness memberships.",
        "The interest rate is too high.",
        "The customer service is very polite.",
        "I appreciate the extended warranty benefits.",
        "The card offers good rewards on home improvement.",
        "The customer service is very attentive.",
        "I like the rewards program flexibility.",
        "The card offers good rewards on subscriptions.",
        "The customer service is very supportive.",
        "I appreciate the travel insurance.",
        "The card offers good rewards on transportation.",
        "The customer service is very accommodating."
        "The annual fee is too high for the benefits provided.",
        "The rewards program is not as good as other cards.",
        "I had a bad experience with the fraud protection.",
        "The customer service wait time is too long.",
        "The rewards points expire too quickly.",
        "I had a negative experience with the customer service.",
        "The card has a high annual fee.",
        "I had a negative experience with the fraud protection.",
        "The customer service is not very helpful.",
        "The card has a high interest rate.",
        "The customer service is terrible.",
        "I had a problem with the billing statement.",
        "The card has a low credit limit.",
        "The customer service is very unresponsive.",
        "The card has a high annual fee.",
        "The customer service is very rude.",
        "The card has a high interest rate.",
        "The customer service is very unprofessional.",
        "The card has a low credit limit.",
        "The customer service is very slow.",
        "The card has a high annual fee.",
        "The customer service is very unhelpful.",
        "The card has a high interest rate.",
        "The customer service is very inefficient.",
        "The card has a low credit limit.",
        "The customer service is very unknowledgeable.",
        "The card has a high annual fee.",
        "The customer service is very unaccommodating.",
        "I love the cashback offers on this card.",
        "Customer service resolved my issue quickly.",
        "I appreciate the low interest rate.",
        "The mobile app is very convenient.",
        "The credit limit increase process is smooth.",
        "I enjoy the travel benefits.",
        "The card design is sleek and modern.",
        "I like the balance transfer options.",
        "The online account management is user-friendly.",
        "I had a positive experience with the dispute resolution.",
        "I appreciate the purchase protection.",
        "The card offers great discounts on dining.",
        "The rewards program is easy to understand.",
        "The card offers good travel insurance.",
        "The cashback redemption process is simple.",
        "The card has a high credit limit.",
        "I like the extended warranty benefits.",
        "The customer service representatives are knowledgeable.",
        "The card offers good rental car insurance.",
        "The rewards program has a lot of options.",
        "The card is accepted everywhere.",
        "The card offers good fraud protection.",
        "The rewards points accumulate quickly.",
        "The card has no foreign transaction fees.",
        "I appreciate the emergency card replacement service.",
        "The card offers good concierge service.",
        "The rewards program is flexible.",
        "I had a positive experience with the credit limit increase.",
        "The card offers good travel perks.",
        "The customer service is very responsive.",
        "The card offers good purchase protection.",
        "The rewards program is competitive.",
        "The card has a low interest rate.",
        "The card offers good cashback rewards.",
        "The customer service is very helpful.",
        "The card has a low annual fee.",
        "I appreciate the travel benefits.",
        "The card offers good rewards on groceries.",
        "I like the rewards program.",
        "The card offers good rewards on gas.",
        "The customer service is excellent.",
        "I appreciate the balance transfer options.",
        "The card offers good rewards on dining.",
        "I like the travel benefits.",
        "The card offers good rewards on travel.",
        "The customer service is very friendly.",
        "I appreciate the rewards program.",
        "The card offers good rewards on shopping.",
        "The customer service is very professional.",
        "I like the cashback rewards.",
        "The card offers good rewards on entertainment.",
        "The customer service is very courteous.",
        "I appreciate the fraud protection.",
        "The card offers good rewards on utilities.",
        "The customer service is very efficient.",
        "I like the rewards program options.",
        "The card offers good rewards on online shopping.",
        "The customer service is very knowledgeable.",
        "I appreciate the purchase protection.",
        "The card offers good rewards on streaming services.",
        "The customer service is very prompt."
    ]
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Review: I like the travel rewards.
# Sentiment: Positive
#
# Review: The card offers good rewards on fitness memberships.
# Sentiment: Negative
#
# Review: The customer service is very polite.
# Sentiment: Negative
#
# Review: I appreciate the extended warranty benefits.
# Sentiment: Positive
#
# Review: The card offers good rewards on home improvement.
# Sentiment: Negative
#
# Review: The customer service is very attentive.
# Sentiment: Negative
#
# Review: I like the rewards program flexibility.
# Sentiment: Positive
#
# Review: The card offers good rewards on subscriptions.
# Sentiment: Negative
#
# ...
